# %% [markdown]
# <a href="https://colab.research.google.com/github/missaelrmzport-create/missael-ramirez-alan-ortiz.ipynb/blob/main/missael_ramirez%2Calan_ortiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
estudiantes = pd.read_csv('datasets/Estuduantes.csv', sep=',')
estudiantes
# Out:
#       NOMBRE  EDAD     GENERO  PROMEDIO
# 0    Braulio    19  Masculino        77
# 1     Mihael    19  Masculino        82
# 2     Aseret    19   Femenino        86
# 3      Josue    18  Masculino        88
# 4       Aldo    22  Masculino        80
# 5       Ivan    19  Masculino        72
# 6    Vanessa    19   Femenino        73
# 7   Gabriela    17   Femenino        71
# 8    Missael    19  Masculino        75
# 9       Alan    19  Masculino        70
# 10    Alexis    19  Masculino        90
# 11    Brayan    19  Masculino        87
# 12     Diego    19  Masculino        85
# 13      Luis    20  Masculino        80
# 14     Efren    20  Masculino        78
# 15     yamil    22  Masculino        82

# %%
estudiantes["GENERO"].describe()
# Out:
# count            16
# unique            2
# top       Masculino
# freq             13
# Name: GENERO, dtype: object

# %%
estudiantes["EDAD"].describe()
# Out:
# count    16.0000
# mean     19.3125
# std       1.2500
# min      17.0000
# 25%      19.0000
# 50%      19.0000
# 75%      19.2500
# max      22.0000
# Name: EDAD, dtype: float64

# %%
media_promedio = estudiantes["PROMEDIO"].mean()
estudiantes["PROMEDIO"].map(lambda promedio: promedio - media_promedio)
# Out:
# 0     -2.75
# 1      2.25
# 2      6.25
# 3      8.25
# 4      0.25
# 5     -7.75
# 6     -6.75
# 7     -8.75
# 8     -4.75
# 9     -9.75
# 10    10.25
# 11     7.25
# 12     5.25
# 13     0.25
# 14    -1.75
# 15     2.25
# Name: PROMEDIO, dtype: float64

# %%
#En resumen hicimos un codigo el cual sacamos y desscribimos la edad i el genero con un (.describe()) tambien mapeamos el promedio de los alumnos
